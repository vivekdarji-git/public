# %% [markdown]
# <a href="https://colab.research.google.com/github/vivekdarji-git/public/blob/master/About_Gradient_Descent_tensorflow2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **SOMETHING ABOUT GRADIENT DESCENT**

# %%
#PREDICTIONS: y = ax + b (a = weight, b = bias)
#example - binary classfication - log loss (Binary crossentropy) - learning on a very small dataset

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("drive/My Drive/Colab Notebooks/samp_data/insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age','affordibility']], df.bought_insurance, test_size=0.2, random_state = 25)

# %%
max(X_train['age'])
# Out:
# 62

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] / 100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape = (2,), activation = 'sigmoid', kernel_initializer='ones', bias_initializer = 'zeros')
])

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
model.fit(X_train_scaled, y_train, epochs = 5000)

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5855 - accuracy: 0.6667
# [0.5854933857917786, 0.6666666865348816]

# %%
#predictions

model.predict(X_test_scaled)
# Out:
# array([[0.64471424],
#        [0.5669487 ],
#        [0.40433866],
#        [0.5943528 ],
#        [0.64985454],
#        [0.67993903]], dtype=float32)
